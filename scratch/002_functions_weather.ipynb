# %%
from src import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-90-88cb1fa78e56> in <module>
# ----> 1 from src import *
#
# ModuleNotFoundError: No module named 'src'

# %%
import requests
import pandas as pd
from functools import reduce
from operator import add
from timezonefinder import TimezoneFinder

# %%
API_KEY = 'f0ec0abb9b8143349f1130303211901'
WWO_URI = f'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key={API_KEY}&q={{lat}},{{lon}}&format=json&extra=localObsTime,utcDateTime,isDayTime&date={{start}}&enddate={{end}}&tp=1'

# %%
# grab locations historical data
def get_raw_weather_json(*, lat: float, lon: float, start: str, end: str) -> dict:
    """
    Return unprocessed json from WWO api - hourly frequency
    """
    uri = WWO_URI.format(lat=lat,lon=lon,start=start,end=end)
    r = requests.get(uri)
    
    return r.json()

def process_raw_weather_json(*, raw_json: dict, lat: float, lon: float) -> dict:
    
    json = raw_json['data']['weather']
    
    daily_data = []
    hourly_data = []
    for day in json:
        daily_data.append(process_daily_data(raw_daily_json=day))
        hourly_data.append(process_day_of_hourly_data(raw_daily_json=day))
    
    # turn list of lists into list via concat
    hourly_data = reduce(add,hourly_data)
    
    hourly_data = pd.DataFrame.from_dict(hourly_data)
    daily_data = pd.DataFrame.from_dict(daily_data)
    
    tf = TimezoneFinder()
    tz = tf.timezone_at(lng=lon, lat=lat)
    
    df = pd.merge(hourly_data,daily_data,how='left',on='date')
    df = df.assign(
        utc_datetime = df.apply(lambda x: parse_datetime(x.UTCdate,x.UTCtime),axis=1),
        local_datetime = df.apply(lambda x: parse_datetime(x.date,x.time,tz),axis=1)
    )
    
    df = df.drop(['date','time', 'UTCdate', 'UTCtime'], axis=1)
    
    return df

def process_day_of_hourly_data(*,raw_daily_json:dict):
    # make a copy
    json = dict(raw_daily_json)
    
    date = json['date'] # need to join to the daily attributes
    hourly = json['hourly']
    
    hourly = [process_hourly_data(raw_hourly_json=raw_hourly_json,date=date) for raw_hourly_json in hourly]
    
    return hourly

def process_hourly_data(*, raw_hourly_json: dict, date: str):
    
    json = dict(raw_hourly_json)
    
    del json['weatherIconUrl'] # dont need!
    json['weatherDesc'] = json['weatherDesc'][0]['value']
    json['date'] = date
    
    return json
    
def process_daily_data(*,raw_daily_json:dict):
    
    # make a copy
    json = dict(raw_daily_json)
    
    # flatten the astro data
    astro = json['astronomy'][0]
    json.update(astro)
    
    # remove unneeded keys
    del json['astronomy']
    del json['hourly']
    
    return json

def parse_datetime(date: str, hour: str, tz: str = "UTC") -> str:
    """[summary]

    Args:
        date (str): [description]
        hour (str): [description]
        tz (str, optional): [description]. Defaults to None.

    Returns:
        str: [description]
    """
    datetime = pendulum.from_format(
        f"{date} {int(int(hour) / 100)}", "YYYY-MM-DD H", tz=tz
    )

    return str(datetime)

# %%
tz = 23
tz if tz else 'UTC'
# Out:
# 23

# %%
raw_json = get_raw_weather_json(lat=33.0047,lon=115.8448,start='2020-01-01',end='2020-01-18')
raw_json
# Out:
# {'data': {'request': [{'type': 'LatLon', 'query': 'Lat 33.00 and Lon 115.84'}],
#   'weather': [{'date': '2020-01-01',
#     'astronomy': [{'sunrise': '07:20 AM',
#       'sunset': '05:20 PM',
#       'moonrise': '11:24 AM',
#       'moonset': '10:58 PM',
#       'moon_phase': 'Waxing Crescent',
#       'moon_illumination': '37'}],
#     'maxtempC': '5',
#     'maxtempF': '41',
#     'mintempC': '-2',
#     'mintempF': '29',
#     'avgtempC': '3',
#     'avgtempF': '37',
#     'totalSnow_cm': '0.0',
#     'sunHour': '3.8',
#     'uvIndex': '1',
#     'hourly': [{'time': '0',
#       'UTCdate': '2019-12-31',
#       'UTCtime': '1600',
#       'isdaytime': 'no',
#       'tempC': '0',
#       'tempF': '33',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '124',
#       'winddir16Point': 'ESE',
#       'weatherCode': '119',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#       'weatherDesc': [{'value': 'Cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '57',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1033',
#       'pressureInches': '31',
#       'cloudcover': '31',
#       'HeatIndexC': '0',
#       'HeatIndexF': '33',
#       'DewPointC': '-7',
#       'DewPointF': '19',
#       'WindChillC': '-3',
#       'WindChillF': '27',
#       'WindGustMiles': '10',
#       'WindGustKmph': '16',
#       'FeelsLikeC': '-3',
#       'FeelsLikeF': '27',
#       'uvIndex': '1'},
#      {'time': '100',
#       'UTCdate': '2019-12-31',
#       'UTCtime': '1700',
#       'isdaytime': 'no',
#       'tempC': '0',
#       'tempF': '32',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '123',
#       'winddir16Point': 'ESE',
#       'weatherCode': '119',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#       'weatherDesc': [{'value': 'Cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '60',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1033',
#       'pressureInches': '31',
#       'cloudcover': '45',
#       'HeatIndexC': '0',
#       'HeatIndexF': '32',
#       'DewPointC': '-7',
#       'DewPointF': '20',
#       'WindChillC': '-3',
#       'WindChillF': '26',
#       'WindGustMiles': '10',
#       'WindGustKmph': '16',
#       'FeelsLikeC': '-3',
#       'FeelsLikeF': '26',
#       'uvIndex': '1'},
#      {'time': '200',
#       'UTCdate': '2019-12-31',
#       'UTCtime': '1800',
#       'isdaytime': 'no',
#       'tempC': '0',
#       'tempF': '32',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '123',
#       'winddir16Point': 'ESE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '63',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1032',
#       'pressureInches': '31',
#       'cloudcover': '59',
#       'HeatIndexC': '0',
#       'HeatIndexF': '32',
#       'DewPointC': '-6',
#       'DewPointF': '21',
#       'WindChillC': '-3',
#       'WindChillF': '26',
#       'WindGustMiles': '10',
#       'WindGustKmph': '16',
#       'FeelsLikeC': '-3',
#       'FeelsLikeF': '26',
#       'uvIndex': '1'},
#      {'time': '300',
#       'UTCdate': '2019-12-31',
#       'UTCtime': '1900',
#       'isdaytime': 'no',
#       'tempC': '-0',
#       'tempF': '32',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '123',
#       'winddir16Point': 'ESE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '66',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1032',
#       'pressureInches': '31',
#       'cloudcover': '72',
#       'HeatIndexC': '-0',
#       'HeatIndexF': '32',
#       'DewPointC': '-6',
#       'DewPointF': '22',
#       'WindChillC': '-3',
#       'WindChillF': '26',
#       'WindGustMiles': '10',
#       'WindGustKmph': '16',
#       'FeelsLikeC': '-3',
#       'FeelsLikeF': '26',
#       'uvIndex': '1'},
#      {'time': '400',
#       'UTCdate': '2019-12-31',
#       'UTCtime': '2000',
#       'isdaytime': 'no',
#       'tempC': '-0',
#       'tempF': '32',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '122',
#       'winddir16Point': 'ESE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '68',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1031',
#       'pressureInches': '31',
#       'cloudcover': '70',
#       'HeatIndexC': '-0',
#       'HeatIndexF': '32',
#       'DewPointC': '-5',
#       'DewPointF': '22',
#       'WindChillC': '-3',
#       'WindChillF': '26',
#       'WindGustMiles': '10',
#       'WindGustKmph': '16',
#       'FeelsLikeC': '-3',
#       'FeelsLikeF': '26',
#       'uvIndex': '1'},
#      {'time': '500',
#       'UTCdate': '2019-12-31',
#       'UTCtime': '2100',
#       'isdaytime': 'no',
#       'tempC': '0',
#       'tempF': '32',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '120',
#       'winddir16Point': 'ESE',
#       'weatherCode': '119',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#       'weatherDesc': [{'value': 'Cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '69',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1031',
#       'pressureInches': '31',
#       'cloudcover': '68',
#       'HeatIndexC': '0',
#       'HeatIndexF': '32',
#       'DewPointC': '-5',
#       'DewPointF': '23',
#       'WindChillC': '-3',
#       'WindChillF': '26',
#       'WindGustMiles': '10',
#       'WindGustKmph': '16',
#       'FeelsLikeC': '-3',
#       'FeelsLikeF': '26',
#       'uvIndex': '1'},
#      {'time': '600',
#       'UTCdate': '2019-12-31',
#       'UTCtime': '2200',
#       'isdaytime': 'yes',
#       'tempC': '0',
#       'tempF': '32',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '119',
#       'winddir16Point': 'ESE',
#       'weatherCode': '119',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#       'weatherDesc': [{'value': 'Cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '71',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1031',
#       'pressureInches': '31',
#       'cloudcover': '66',
#       'HeatIndexC': '0',
#       'HeatIndexF': '32',
#       'DewPointC': '-5',
#       'DewPointF': '24',
#       'WindChillC': '-3',
#       'WindChillF': '26',
#       'WindGustMiles': '10',
#       'WindGustKmph': '17',
#       'FeelsLikeC': '-3',
#       'FeelsLikeF': '26',
#       'uvIndex': '1'},
#      {'time': '700',
#       'UTCdate': '2019-12-31',
#       'UTCtime': '2300',
#       'isdaytime': 'yes',
#       'tempC': '1',
#       'tempF': '33',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '122',
#       'winddir16Point': 'ESE',
#       'weatherCode': '119',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#       'weatherDesc': [{'value': 'Cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '71',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1031',
#       'pressureInches': '31',
#       'cloudcover': '72',
#       'HeatIndexC': '1',
#       'HeatIndexF': '33',
#       'DewPointC': '-4',
#       'DewPointF': '25',
#       'WindChillC': '-3',
#       'WindChillF': '27',
#       'WindGustMiles': '10',
#       'WindGustKmph': '16',
#       'FeelsLikeC': '-3',
#       'FeelsLikeF': '27',
#       'uvIndex': '1'},
#      {'time': '800',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '0',
#       'isdaytime': 'yes',
#       'tempC': '1',
#       'tempF': '34',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '124',
#       'winddir16Point': 'SE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '70',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1031',
#       'pressureInches': '31',
#       'cloudcover': '79',
#       'HeatIndexC': '1',
#       'HeatIndexF': '34',
#       'DewPointC': '-4',
#       'DewPointF': '25',
#       'WindChillC': '-2',
#       'WindChillF': '28',
#       'WindGustMiles': '10',
#       'WindGustKmph': '15',
#       'FeelsLikeC': '-2',
#       'FeelsLikeF': '28',
#       'uvIndex': '1'},
#      {'time': '900',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '100',
#       'isdaytime': 'yes',
#       'tempC': '2',
#       'tempF': '35',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '127',
#       'winddir16Point': 'SE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '70',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1031',
#       'pressureInches': '31',
#       'cloudcover': '85',
#       'HeatIndexC': '2',
#       'HeatIndexF': '35',
#       'DewPointC': '-3',
#       'DewPointF': '26',
#       'WindChillC': '-1',
#       'WindChillF': '29',
#       'WindGustMiles': '9',
#       'WindGustKmph': '15',
#       'FeelsLikeC': '-1',
#       'FeelsLikeF': '29',
#       'uvIndex': '1'},
#      {'time': '1000',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '200',
#       'isdaytime': 'yes',
#       'tempC': '2',
#       'tempF': '36',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '129',
#       'winddir16Point': 'SE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '67',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1031',
#       'pressureInches': '31',
#       'cloudcover': '89',
#       'HeatIndexC': '2',
#       'HeatIndexF': '36',
#       'DewPointC': '-3',
#       'DewPointF': '27',
#       'WindChillC': '-0',
#       'WindChillF': '31',
#       'WindGustMiles': '9',
#       'WindGustKmph': '14',
#       'FeelsLikeC': '-0',
#       'FeelsLikeF': '31',
#       'uvIndex': '1'},
#      {'time': '1100',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '300',
#       'isdaytime': 'yes',
#       'tempC': '3',
#       'tempF': '38',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '130',
#       'winddir16Point': 'SE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '65',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1031',
#       'pressureInches': '31',
#       'cloudcover': '92',
#       'HeatIndexC': '3',
#       'HeatIndexF': '38',
#       'DewPointC': '-3',
#       'DewPointF': '27',
#       'WindChillC': '1',
#       'WindChillF': '33',
#       'WindGustMiles': '8',
#       'WindGustKmph': '13',
#       'FeelsLikeC': '1',
#       'FeelsLikeF': '33',
#       'uvIndex': '1'},
#      {'time': '1200',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '400',
#       'isdaytime': 'yes',
#       'tempC': '4',
#       'tempF': '40',
#       'windspeedMiles': '6',
#       'windspeedKmph': '9',
#       'winddirDegree': '132',
#       'winddir16Point': 'SE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '63',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1031',
#       'pressureInches': '31',
#       'cloudcover': '96',
#       'HeatIndexC': '4',
#       'HeatIndexF': '40',
#       'DewPointC': '-2',
#       'DewPointF': '28',
#       'WindChillC': '2',
#       'WindChillF': '35',
#       'WindGustMiles': '7',
#       'WindGustKmph': '12',
#       'FeelsLikeC': '2',
#       'FeelsLikeF': '35',
#       'uvIndex': '1'},
#      {'time': '1300',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '500',
#       'isdaytime': 'yes',
#       'tempC': '4',
#       'tempF': '40',
#       'windspeedMiles': '6',
#       'windspeedKmph': '9',
#       'winddirDegree': '133',
#       'winddir16Point': 'SE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '63',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1030',
#       'pressureInches': '31',
#       'cloudcover': '97',
#       'HeatIndexC': '4',
#       'HeatIndexF': '40',
#       'DewPointC': '-2',
#       'DewPointF': '28',
#       'WindChillC': '2',
#       'WindChillF': '36',
#       'WindGustMiles': '7',
#       'WindGustKmph': '11',
#       'FeelsLikeC': '2',
#       'FeelsLikeF': '36',
#       'uvIndex': '1'},
#      {'time': '1400',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '600',
#       'isdaytime': 'yes',
#       'tempC': '5',
#       'tempF': '40',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '134',
#       'winddir16Point': 'SE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '64',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1030',
#       'pressureInches': '31',
#       'cloudcover': '99',
#       'HeatIndexC': '5',
#       'HeatIndexF': '40',
#       'DewPointC': '-2',
#       'DewPointF': '29',
#       'WindChillC': '3',
#       'WindChillF': '37',
#       'WindGustMiles': '7',
#       'WindGustKmph': '11',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '37',
#       'uvIndex': '1'},
#      {'time': '1500',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '700',
#       'isdaytime': 'yes',
#       'tempC': '5',
#       'tempF': '41',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '135',
#       'winddir16Point': 'SE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '64',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '5',
#       'HeatIndexF': '41',
#       'DewPointC': '-1',
#       'DewPointF': '29',
#       'WindChillC': '3',
#       'WindChillF': '38',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '38',
#       'uvIndex': '1'},
#      {'time': '1600',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '800',
#       'isdaytime': 'yes',
#       'tempC': '4',
#       'tempF': '40',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '128',
#       'winddir16Point': 'SE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '66',
#       'visibility': '9',
#       'visibilityMiles': '5',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '5',
#       'HeatIndexF': '40',
#       'DewPointC': '-1',
#       'DewPointF': '30',
#       'WindChillC': '3',
#       'WindChillF': '37',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '37',
#       'uvIndex': '1'},
#      {'time': '1700',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '900',
#       'isdaytime': 'yes',
#       'tempC': '4',
#       'tempF': '39',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '121',
#       'winddir16Point': 'ESE',
#       'weatherCode': '266',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0017_cloudy_with_light_rain.png'}],
#       'weatherDesc': [{'value': 'Light drizzle'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '68',
#       'visibility': '8',
#       'visibilityMiles': '5',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '4',
#       'HeatIndexF': '40',
#       'DewPointC': '-1',
#       'DewPointF': '30',
#       'WindChillC': '2',
#       'WindChillF': '36',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '2',
#       'FeelsLikeF': '36',
#       'uvIndex': '1'},
#      {'time': '1800',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '1000',
#       'isdaytime': 'no',
#       'tempC': '3',
#       'tempF': '38',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '114',
#       'winddir16Point': 'ESE',
#       'weatherCode': '266',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0033_cloudy_with_light_rain_night.png'}],
#       'weatherDesc': [{'value': 'Light drizzle'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '69',
#       'visibility': '7',
#       'visibilityMiles': '4',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '4',
#       'HeatIndexF': '39',
#       'DewPointC': '-1',
#       'DewPointF': '31',
#       'WindChillC': '2',
#       'WindChillF': '36',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '2',
#       'FeelsLikeF': '36',
#       'uvIndex': '1'},
#      {'time': '1900',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '1100',
#       'isdaytime': 'no',
#       'tempC': '2',
#       'tempF': '35',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '104',
#       'winddir16Point': 'ESE',
#       'weatherCode': '266',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0033_cloudy_with_light_rain_night.png'}],
#       'weatherDesc': [{'value': 'Light drizzle'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '71',
#       'visibility': '6',
#       'visibilityMiles': '3',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '3',
#       'HeatIndexF': '37',
#       'DewPointC': '-0',
#       'DewPointF': '31',
#       'WindChillC': '1',
#       'WindChillF': '34',
#       'WindGustMiles': '6',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '1',
#       'FeelsLikeF': '34',
#       'uvIndex': '1'},
#      {'time': '2000',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '1200',
#       'isdaytime': 'no',
#       'tempC': '0',
#       'tempF': '32',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '93',
#       'winddir16Point': 'E',
#       'weatherCode': '311',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0037_cloudy_with_sleet_night.png'}],
#       'weatherDesc': [{'value': 'Light freezing rain'}],
#       'precipMM': '0.1',
#       'precipInches': '0.0',
#       'humidity': '72',
#       'visibility': '6',
#       'visibilityMiles': '3',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '2',
#       'HeatIndexF': '35',
#       'DewPointC': '0',
#       'DewPointF': '32',
#       'WindChillC': '-0',
#       'WindChillF': '31',
#       'WindGustMiles': '6',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '-0',
#       'FeelsLikeF': '31',
#       'uvIndex': '1'},
#      {'time': '2100',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '1300',
#       'isdaytime': 'no',
#       'tempC': '-2',
#       'tempF': '29',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '82',
#       'winddir16Point': 'E',
#       'weatherCode': '311',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0037_cloudy_with_sleet_night.png'}],
#       'weatherDesc': [{'value': 'Light freezing rain'}],
#       'precipMM': '0.1',
#       'precipInches': '0.0',
#       'humidity': '73',
#       'visibility': '5',
#       'visibilityMiles': '2',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '1',
#       'HeatIndexF': '33',
#       'DewPointC': '0',
#       'DewPointF': '33',
#       'WindChillC': '-2',
#       'WindChillF': '29',
#       'WindGustMiles': '6',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '-2',
#       'FeelsLikeF': '29',
#       'uvIndex': '1'},
#      {'time': '2200',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '1400',
#       'isdaytime': 'no',
#       'tempC': '-2',
#       'tempF': '29',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '77',
#       'winddir16Point': 'ENE',
#       'weatherCode': '311',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0037_cloudy_with_sleet_night.png'}],
#       'weatherDesc': [{'value': 'Light freezing rain'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '74',
#       'visibility': '6',
#       'visibilityMiles': '4',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '0',
#       'HeatIndexF': '33',
#       'DewPointC': '0',
#       'DewPointF': '32',
#       'WindChillC': '-2',
#       'WindChillF': '29',
#       'WindGustMiles': '6',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '-2',
#       'FeelsLikeF': '29',
#       'uvIndex': '1'},
#      {'time': '2300',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '1500',
#       'isdaytime': 'no',
#       'tempC': '-2',
#       'tempF': '29',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '71',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0025_light_rain_showers_night.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '74',
#       'visibility': '8',
#       'visibilityMiles': '5',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '0',
#       'HeatIndexF': '32',
#       'DewPointC': '-0',
#       'DewPointF': '31',
#       'WindChillC': '-2',
#       'WindChillF': '28',
#       'WindGustMiles': '6',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '-2',
#       'FeelsLikeF': '28',
#       'uvIndex': '1'}]},
#    {'date': '2020-01-02',
#     'astronomy': [{'sunrise': '07:20 AM',
#       'sunset': '05:21 PM',
#       'moonrise': '11:53 AM',
#       'moonset': '11:52 PM',
#       'moon_phase': 'First Quarter',
#       'moon_illumination': '44'}],
#     'maxtempC': '7',
#     'maxtempF': '45',
#     'mintempC': '-2',
#     'mintempF': '29',
#     'avgtempC': '6',
#     'avgtempF': '42',
#     'totalSnow_cm': '0.0',
#     'sunHour': '3.8',
#     'uvIndex': '2',
#     'hourly': [{'time': '0',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '1600',
#       'isdaytime': 'no',
#       'tempC': '-2',
#       'tempF': '29',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '66',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0025_light_rain_showers_night.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '75',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '-0',
#       'HeatIndexF': '31',
#       'DewPointC': '-1',
#       'DewPointF': '31',
#       'WindChillC': '-2',
#       'WindChillF': '28',
#       'WindGustMiles': '6',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '-2',
#       'FeelsLikeF': '28',
#       'uvIndex': '1'},
#      {'time': '100',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '1700',
#       'isdaytime': 'no',
#       'tempC': '0',
#       'tempF': '32',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '63',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0025_light_rain_showers_night.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '76',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '1',
#       'HeatIndexF': '34',
#       'DewPointC': '-0',
#       'DewPointF': '31',
#       'WindChillC': '-1',
#       'WindChillF': '30',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '-1',
#       'FeelsLikeF': '30',
#       'uvIndex': '1'},
#      {'time': '200',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '1800',
#       'isdaytime': 'no',
#       'tempC': '2',
#       'tempF': '35',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '61',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0025_light_rain_showers_night.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '77',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '2',
#       'HeatIndexF': '36',
#       'DewPointC': '-0',
#       'DewPointF': '32',
#       'WindChillC': '0',
#       'WindChillF': '33',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '0',
#       'FeelsLikeF': '33',
#       'uvIndex': '1'},
#      {'time': '300',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '1900',
#       'isdaytime': 'no',
#       'tempC': '4',
#       'tempF': '39',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '58',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0025_light_rain_showers_night.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '78',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '4',
#       'HeatIndexF': '39',
#       'DewPointC': '0',
#       'DewPointF': '32',
#       'WindChillC': '2',
#       'WindChillF': '35',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '2',
#       'FeelsLikeF': '35',
#       'uvIndex': '1'},
#      {'time': '400',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '2000',
#       'isdaytime': 'no',
#       'tempC': '4',
#       'tempF': '39',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '58',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0025_light_rain_showers_night.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '79',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '4',
#       'HeatIndexF': '39',
#       'DewPointC': '0',
#       'DewPointF': '33',
#       'WindChillC': '2',
#       'WindChillF': '36',
#       'WindGustMiles': '6',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '2',
#       'FeelsLikeF': '36',
#       'uvIndex': '1'},
#      {'time': '500',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '2100',
#       'isdaytime': 'no',
#       'tempC': '4',
#       'tempF': '39',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '58',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0025_light_rain_showers_night.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '80',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '4',
#       'HeatIndexF': '39',
#       'DewPointC': '1',
#       'DewPointF': '33',
#       'WindChillC': '2',
#       'WindChillF': '36',
#       'WindGustMiles': '6',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '2',
#       'FeelsLikeF': '36',
#       'uvIndex': '1'},
#      {'time': '600',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '2200',
#       'isdaytime': 'yes',
#       'tempC': '4',
#       'tempF': '39',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '58',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '81',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '4',
#       'HeatIndexF': '39',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '3',
#       'WindChillF': '37',
#       'WindGustMiles': '5',
#       'WindGustKmph': '8',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '37',
#       'uvIndex': '1'},
#      {'time': '700',
#       'UTCdate': '2020-01-01',
#       'UTCtime': '2300',
#       'isdaytime': 'yes',
#       'tempC': '4',
#       'tempF': '40',
#       'windspeedMiles': '3',
#       'windspeedKmph': '6',
#       'winddirDegree': '58',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '81',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '4',
#       'HeatIndexF': '40',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '3',
#       'WindChillF': '37',
#       'WindGustMiles': '5',
#       'WindGustKmph': '8',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '37',
#       'uvIndex': '1'},
#      {'time': '800',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '0',
#       'isdaytime': 'yes',
#       'tempC': '4',
#       'tempF': '40',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '57',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '80',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1030',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '4',
#       'HeatIndexF': '40',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '3',
#       'WindChillF': '38',
#       'WindGustMiles': '5',
#       'WindGustKmph': '8',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '38',
#       'uvIndex': '1'},
#      {'time': '900',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '100',
#       'isdaytime': 'yes',
#       'tempC': '5',
#       'tempF': '40',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '57',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '80',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1030',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '5',
#       'HeatIndexF': '40',
#       'DewPointC': '2',
#       'DewPointF': '35',
#       'WindChillC': '4',
#       'WindChillF': '39',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '4',
#       'FeelsLikeF': '39',
#       'uvIndex': '1'},
#      {'time': '1000',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '200',
#       'isdaytime': 'yes',
#       'tempC': '5',
#       'tempF': '41',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '58',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '79',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1030',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '5',
#       'HeatIndexF': '41',
#       'DewPointC': '2',
#       'DewPointF': '35',
#       'WindChillC': '4',
#       'WindChillF': '40',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '4',
#       'FeelsLikeF': '40',
#       'uvIndex': '2'},
#      {'time': '1100',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '300',
#       'isdaytime': 'yes',
#       'tempC': '6',
#       'tempF': '42',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '59',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '78',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1030',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '6',
#       'HeatIndexF': '42',
#       'DewPointC': '2',
#       'DewPointF': '36',
#       'WindChillC': '5',
#       'WindChillF': '41',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '5',
#       'FeelsLikeF': '41',
#       'uvIndex': '2'},
#      {'time': '1200',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '400',
#       'isdaytime': 'yes',
#       'tempC': '6',
#       'tempF': '43',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '60',
#       'winddir16Point': 'ENE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '77',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1030',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '6',
#       'HeatIndexF': '43',
#       'DewPointC': '3',
#       'DewPointF': '37',
#       'WindChillC': '5',
#       'WindChillF': '42',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '5',
#       'FeelsLikeF': '42',
#       'uvIndex': '2'},
#      {'time': '1300',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '500',
#       'isdaytime': 'yes',
#       'tempC': '7',
#       'tempF': '44',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '56',
#       'winddir16Point': 'NE',
#       'weatherCode': '176',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0009_light_rain_showers.png'}],
#       'weatherDesc': [{'value': 'Patchy rain possible'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '76',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '7',
#       'HeatIndexF': '44',
#       'DewPointC': '3',
#       'DewPointF': '37',
#       'WindChillC': '6',
#       'WindChillF': '42',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '6',
#       'FeelsLikeF': '42',
#       'uvIndex': '2'},
#      {'time': '1400',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '600',
#       'isdaytime': 'yes',
#       'tempC': '7',
#       'tempF': '45',
#       'windspeedMiles': '3',
#       'windspeedKmph': '6',
#       'winddirDegree': '52',
#       'winddir16Point': 'NE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '75',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '7',
#       'HeatIndexF': '45',
#       'DewPointC': '3',
#       'DewPointF': '37',
#       'WindChillC': '6',
#       'WindChillF': '43',
#       'WindGustMiles': '5',
#       'WindGustKmph': '8',
#       'FeelsLikeC': '6',
#       'FeelsLikeF': '43',
#       'uvIndex': '2'},
#      {'time': '1500',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '700',
#       'isdaytime': 'yes',
#       'tempC': '7',
#       'tempF': '45',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '49',
#       'winddir16Point': 'NE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '74',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '31',
#       'cloudcover': '100',
#       'HeatIndexC': '7',
#       'HeatIndexF': '45',
#       'DewPointC': '3',
#       'DewPointF': '38',
#       'WindChillC': '7',
#       'WindChillF': '44',
#       'WindGustMiles': '5',
#       'WindGustKmph': '8',
#       'FeelsLikeC': '7',
#       'FeelsLikeF': '44',
#       'uvIndex': '2'},
#      {'time': '1600',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '800',
#       'isdaytime': 'yes',
#       'tempC': '7',
#       'tempF': '45',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '50',
#       'winddir16Point': 'NE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '75',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '31',
#       'cloudcover': '99',
#       'HeatIndexC': '7',
#       'HeatIndexF': '45',
#       'DewPointC': '3',
#       'DewPointF': '38',
#       'WindChillC': '6',
#       'WindChillF': '43',
#       'WindGustMiles': '6',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '6',
#       'FeelsLikeF': '43',
#       'uvIndex': '2'},
#      {'time': '1700',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '900',
#       'isdaytime': 'yes',
#       'tempC': '7',
#       'tempF': '45',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '51',
#       'winddir16Point': 'NE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '76',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '31',
#       'cloudcover': '99',
#       'HeatIndexC': '7',
#       'HeatIndexF': '45',
#       'DewPointC': '3',
#       'DewPointF': '38',
#       'WindChillC': '6',
#       'WindChillF': '42',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '6',
#       'FeelsLikeF': '42',
#       'uvIndex': '2'},
#      {'time': '1800',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '1000',
#       'isdaytime': 'no',
#       'tempC': '7',
#       'tempF': '44',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '52',
#       'winddir16Point': 'NE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '78',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '98',
#       'HeatIndexC': '7',
#       'HeatIndexF': '44',
#       'DewPointC': '3',
#       'DewPointF': '38',
#       'WindChillC': '5',
#       'WindChillF': '42',
#       'WindGustMiles': '7',
#       'WindGustKmph': '11',
#       'FeelsLikeC': '5',
#       'FeelsLikeF': '42',
#       'uvIndex': '1'},
#      {'time': '1900',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '1100',
#       'isdaytime': 'no',
#       'tempC': '7',
#       'tempF': '44',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '52',
#       'winddir16Point': 'NE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '80',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '96',
#       'HeatIndexC': '7',
#       'HeatIndexF': '44',
#       'DewPointC': '3',
#       'DewPointF': '38',
#       'WindChillC': '5',
#       'WindChillF': '41',
#       'WindGustMiles': '7',
#       'WindGustKmph': '11',
#       'FeelsLikeC': '5',
#       'FeelsLikeF': '41',
#       'uvIndex': '1'},
#      {'time': '2000',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '1200',
#       'isdaytime': 'no',
#       'tempC': '6',
#       'tempF': '43',
#       'windspeedMiles': '5',
#       'windspeedKmph': '7',
#       'winddirDegree': '51',
#       'winddir16Point': 'NE',
#       'weatherCode': '119',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#       'weatherDesc': [{'value': 'Cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '82',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '94',
#       'HeatIndexC': '6',
#       'HeatIndexF': '43',
#       'DewPointC': '3',
#       'DewPointF': '38',
#       'WindChillC': '5',
#       'WindChillF': '41',
#       'WindGustMiles': '7',
#       'WindGustKmph': '11',
#       'FeelsLikeC': '5',
#       'FeelsLikeF': '41',
#       'uvIndex': '1'},
#      {'time': '2100',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '1300',
#       'isdaytime': 'no',
#       'tempC': '6',
#       'tempF': '43',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '51',
#       'winddir16Point': 'NE',
#       'weatherCode': '119',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#       'weatherDesc': [{'value': 'Cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '84',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '92',
#       'HeatIndexC': '6',
#       'HeatIndexF': '43',
#       'DewPointC': '3',
#       'DewPointF': '38',
#       'WindChillC': '4',
#       'WindChillF': '40',
#       'WindGustMiles': '7',
#       'WindGustKmph': '11',
#       'FeelsLikeC': '4',
#       'FeelsLikeF': '40',
#       'uvIndex': '1'},
#      {'time': '2200',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '1400',
#       'isdaytime': 'no',
#       'tempC': '6',
#       'tempF': '43',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '45',
#       'winddir16Point': 'NE',
#       'weatherCode': '119',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#       'weatherDesc': [{'value': 'Cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '84',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '92',
#       'HeatIndexC': '6',
#       'HeatIndexF': '43',
#       'DewPointC': '3',
#       'DewPointF': '38',
#       'WindChillC': '5',
#       'WindChillF': '40',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '5',
#       'FeelsLikeF': '40',
#       'uvIndex': '1'},
#      {'time': '2300',
#       'UTCdate': '2020-01-02',
#       'UTCtime': '1500',
#       'isdaytime': 'no',
#       'tempC': '6',
#       'tempF': '43',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '39',
#       'winddir16Point': 'NE',
#       'weatherCode': '122',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Overcast'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '84',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1029',
#       'pressureInches': '31',
#       'cloudcover': '92',
#       'HeatIndexC': '6',
#       'HeatIndexF': '43',
#       'DewPointC': '4',
#       'DewPointF': '38',
#       'WindChillC': '5',
#       'WindChillF': '40',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '5',
#       'FeelsLikeF': '40',
#       'uvIndex': '1'}]},
#    {'date': '2020-01-03',
#     'astronomy': [{'sunrise': '07:20 AM',
#       'sunset': '05:22 PM',
#       'moonrise': '12:21 PM',
#       'moonset': 'No moonset',
#       'moon_phase': 'First Quarter',
#       'moon_illumination': '51'}],
#     'maxtempC': '9',
#     'maxtempF': '48',
#     'mintempC': '6',
#     'mintempF': '42',
#     'avgtempC': '8',
#     'avgtempF': '46',
# ...
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '85',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '31',
#       'cloudcover': '10',
#       'HeatIndexC': '3',
#       'HeatIndexF': '37',
#       'DewPointC': '1',
#       'DewPointF': '33',
#       'WindChillC': '2',
#       'WindChillF': '35',
#       'WindGustMiles': '4',
#       'WindGustKmph': '6',
#       'FeelsLikeC': '2',
#       'FeelsLikeF': '35',
#       'uvIndex': '2'},
#      {'time': '800',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '0',
#       'isdaytime': 'yes',
#       'tempC': '4',
#       'tempF': '39',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '153',
#       'winddir16Point': 'SSE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '82',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '31',
#       'cloudcover': '6',
#       'HeatIndexC': '4',
#       'HeatIndexF': '39',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '3',
#       'WindChillF': '37',
#       'WindGustMiles': '4',
#       'WindGustKmph': '6',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '37',
#       'uvIndex': '2'},
#      {'time': '900',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '100',
#       'isdaytime': 'yes',
#       'tempC': '5',
#       'tempF': '40',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '157',
#       'winddir16Point': 'SSE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '79',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '31',
#       'cloudcover': '2',
#       'HeatIndexC': '5',
#       'HeatIndexF': '40',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '3',
#       'WindChillF': '38',
#       'WindGustMiles': '4',
#       'WindGustKmph': '6',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '38',
#       'uvIndex': '2'},
#      {'time': '1000',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '200',
#       'isdaytime': 'yes',
#       'tempC': '5',
#       'tempF': '42',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '162',
#       'winddir16Point': 'SSE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '74',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '31',
#       'cloudcover': '4',
#       'HeatIndexC': '5',
#       'HeatIndexF': '42',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '4',
#       'WindChillF': '40',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '4',
#       'FeelsLikeF': '40',
#       'uvIndex': '3'},
#      {'time': '1100',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '300',
#       'isdaytime': 'yes',
#       'tempC': '6',
#       'tempF': '43',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '167',
#       'winddir16Point': 'SSE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '69',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '31',
#       'cloudcover': '6',
#       'HeatIndexC': '6',
#       'HeatIndexF': '43',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '5',
#       'WindChillF': '41',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '5',
#       'FeelsLikeF': '41',
#       'uvIndex': '3'},
#      {'time': '1200',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '400',
#       'isdaytime': 'yes',
#       'tempC': '7',
#       'tempF': '45',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '172',
#       'winddir16Point': 'S',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '64',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1027',
#       'pressureInches': '31',
#       'cloudcover': '8',
#       'HeatIndexC': '7',
#       'HeatIndexF': '45',
#       'DewPointC': '1',
#       'DewPointF': '33',
#       'WindChillC': '6',
#       'WindChillF': '43',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '6',
#       'FeelsLikeF': '43',
#       'uvIndex': '3'},
#      {'time': '1300',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '500',
#       'isdaytime': 'yes',
#       'tempC': '7',
#       'tempF': '45',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '183',
#       'winddir16Point': 'S',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '63',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1027',
#       'pressureInches': '31',
#       'cloudcover': '12',
#       'HeatIndexC': '7',
#       'HeatIndexF': '45',
#       'DewPointC': '1',
#       'DewPointF': '33',
#       'WindChillC': '6',
#       'WindChillF': '44',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '6',
#       'FeelsLikeF': '44',
#       'uvIndex': '3'},
#      {'time': '1400',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '600',
#       'isdaytime': 'yes',
#       'tempC': '8',
#       'tempF': '46',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '194',
#       'winddir16Point': 'SSW',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '61',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1026',
#       'pressureInches': '31',
#       'cloudcover': '15',
#       'HeatIndexC': '8',
#       'HeatIndexF': '46',
#       'DewPointC': '1',
#       'DewPointF': '33',
#       'WindChillC': '7',
#       'WindChillF': '44',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '7',
#       'FeelsLikeF': '44',
#       'uvIndex': '3'},
#      {'time': '1500',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '700',
#       'isdaytime': 'yes',
#       'tempC': '8',
#       'tempF': '47',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '205',
#       'winddir16Point': 'SSW',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '60',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '31',
#       'cloudcover': '19',
#       'HeatIndexC': '8',
#       'HeatIndexF': '47',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '7',
#       'WindChillF': '45',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '7',
#       'FeelsLikeF': '45',
#       'uvIndex': '3'},
#      {'time': '1600',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '800',
#       'isdaytime': 'yes',
#       'tempC': '8',
#       'tempF': '46',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '205',
#       'winddir16Point': 'SSW',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '62',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '31',
#       'cloudcover': '24',
#       'HeatIndexC': '8',
#       'HeatIndexF': '46',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '7',
#       'WindChillF': '44',
#       'WindGustMiles': '5',
#       'WindGustKmph': '8',
#       'FeelsLikeC': '7',
#       'FeelsLikeF': '44',
#       'uvIndex': '3'},
#      {'time': '1700',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '900',
#       'isdaytime': 'yes',
#       'tempC': '7',
#       'tempF': '45',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '206',
#       'winddir16Point': 'SSW',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '65',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '31',
#       'cloudcover': '29',
#       'HeatIndexC': '7',
#       'HeatIndexF': '45',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '6',
#       'WindChillF': '43',
#       'WindGustMiles': '6',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '6',
#       'FeelsLikeF': '43',
#       'uvIndex': '3'},
#      {'time': '1800',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '1000',
#       'isdaytime': 'no',
#       'tempC': '7',
#       'tempF': '44',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '206',
#       'winddir16Point': 'SSW',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '67',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '31',
#       'cloudcover': '34',
#       'HeatIndexC': '7',
#       'HeatIndexF': '44',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '6',
#       'WindChillF': '42',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '6',
#       'FeelsLikeF': '42',
#       'uvIndex': '1'},
#      {'time': '1900',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '1100',
#       'isdaytime': 'no',
#       'tempC': '6',
#       'tempF': '43',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '202',
#       'winddir16Point': 'SSW',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '70',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '31',
#       'cloudcover': '39',
#       'HeatIndexC': '6',
#       'HeatIndexF': '43',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '5',
#       'WindChillF': '41',
#       'WindGustMiles': '8',
#       'WindGustKmph': '12',
#       'FeelsLikeC': '5',
#       'FeelsLikeF': '41',
#       'uvIndex': '1'},
#      {'time': '2000',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '1200',
#       'isdaytime': 'no',
#       'tempC': '6',
#       'tempF': '42',
#       'windspeedMiles': '5',
#       'windspeedKmph': '9',
#       'winddirDegree': '198',
#       'winddir16Point': 'SSW',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '72',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '31',
#       'cloudcover': '43',
#       'HeatIndexC': '6',
#       'HeatIndexF': '42',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '4',
#       'WindChillF': '39',
#       'WindGustMiles': '9',
#       'WindGustKmph': '14',
#       'FeelsLikeC': '4',
#       'FeelsLikeF': '39',
#       'uvIndex': '1'},
#      {'time': '2100',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '1300',
#       'isdaytime': 'no',
#       'tempC': '5',
#       'tempF': '41',
#       'windspeedMiles': '6',
#       'windspeedKmph': '9',
#       'winddirDegree': '194',
#       'winddir16Point': 'SSW',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '74',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '31',
#       'cloudcover': '48',
#       'HeatIndexC': '5',
#       'HeatIndexF': '41',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '3',
#       'WindChillF': '38',
#       'WindGustMiles': '10',
#       'WindGustKmph': '16',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '38',
#       'uvIndex': '1'},
#      {'time': '2200',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '1400',
#       'isdaytime': 'no',
#       'tempC': '5',
#       'tempF': '41',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '203',
#       'winddir16Point': 'SSW',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '75',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '31',
#       'cloudcover': '49',
#       'HeatIndexC': '5',
#       'HeatIndexF': '41',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '2',
#       'WindChillF': '36',
#       'WindGustMiles': '11',
#       'WindGustKmph': '18',
#       'FeelsLikeC': '2',
#       'FeelsLikeF': '36',
#       'uvIndex': '1'},
#      {'time': '2300',
#       'UTCdate': '2020-01-18',
#       'UTCtime': '1500',
#       'isdaytime': 'no',
#       'tempC': '4',
#       'tempF': '40',
#       'windspeedMiles': '7',
#       'windspeedKmph': '11',
#       'winddirDegree': '213',
#       'winddir16Point': 'SSW',
#       'weatherCode': '119',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0003_white_cloud.png'}],
#       'weatherDesc': [{'value': 'Cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '77',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '31',
#       'cloudcover': '51',
#       'HeatIndexC': '4',
#       'HeatIndexF': '40',
#       'DewPointC': '1',
#       'DewPointF': '33',
#       'WindChillC': '2',
#       'WindChillF': '35',
#       'WindGustMiles': '12',
#       'WindGustKmph': '20',
#       'FeelsLikeC': '2',
#       'FeelsLikeF': '35',
#       'uvIndex': '1'}]}]}}

# %%
df = process_raw_weather_json(raw_json=raw_json,lat=33.0047,lon=115.8448)
df
# Out:
#     isdaytime tempC tempF windspeedMiles windspeedKmph winddirDegree  \
# 0          no     0    33              6            10           124
# 1          no     0    32              6            10           123
# 2          no     0    32              6            10           123
# 3          no    -0    32              6            10           123
# 4          no    -0    32              6            10           122
# ..        ...   ...   ...            ...           ...           ...
# 427        no     6    43              5             8           202
# 428        no     6    42              5             9           198
# 429        no     5    41              6             9           194
# 430        no     5    41              6            10           203
# 431        no     4    40              7            11           213
#
#     winddir16Point weatherCode    weatherDesc precipMM  ... sunHour uvIndex_y  \
# 0              ESE         119         Cloudy      0.0  ...     3.8         1
# 1              ESE         119         Cloudy      0.0  ...     3.8         1
# 2              ESE         116  Partly cloudy      0.0  ...     3.8         1
# 3              ESE         116  Partly cloudy      0.0  ...     3.8         1
# 4              ESE         116  Partly cloudy      0.0  ...     3.8         1
# ..             ...         ...            ...      ...  ...     ...       ...
# 427            SSW         116  Partly cloudy      0.0  ...     8.7         3
# 428            SSW         116  Partly cloudy      0.0  ...     8.7         3
# 429            SSW         116  Partly cloudy      0.0  ...     8.7         3
# 430            SSW         116  Partly cloudy      0.0  ...     8.7         3
# 431            SSW         119         Cloudy      0.0  ...     8.7         3
#
#       sunrise    sunset  moonrise   moonset       moon_phase  \
# 0    07:20 AM  05:20 PM  11:24 AM  10:58 PM  Waxing Crescent
# 1    07:20 AM  05:20 PM  11:24 AM  10:58 PM  Waxing Crescent
# 2    07:20 AM  05:20 PM  11:24 AM  10:58 PM  Waxing Crescent
# 3    07:20 AM  05:20 PM  11:24 AM  10:58 PM  Waxing Crescent
# 4    07:20 AM  05:20 PM  11:24 AM  10:58 PM  Waxing Crescent
# ..        ...       ...       ...       ...              ...
# 427  07:19 AM  05:35 PM  12:43 AM  12:24 PM     Last Quarter
# 428  07:19 AM  05:35 PM  12:43 AM  12:24 PM     Last Quarter
# 429  07:19 AM  05:35 PM  12:43 AM  12:24 PM     Last Quarter
# 430  07:19 AM  05:35 PM  12:43 AM  12:24 PM     Last Quarter
# 431  07:19 AM  05:35 PM  12:43 AM  12:24 PM     Last Quarter
#
#     moon_illumination               utc_datetime             local_datetime
# 0                  37  2019-12-31T16:00:00+00:00  2020-01-01T00:00:00+08:00
# 1                  37  2019-12-31T17:00:00+00:00  2020-01-01T01:00:00+08:00
# 2                  37  2019-12-31T18:00:00+00:00  2020-01-01T02:00:00+08:00
# 3                  37  2019-12-31T19:00:00+00:00  2020-01-01T03:00:00+08:00
# 4                  37  2019-12-31T20:00:00+00:00  2020-01-01T04:00:00+08:00
# ..                ...                        ...                        ...
# 427                40  2020-01-18T11:00:00+00:00  2020-01-18T19:00:00+08:00
# 428                40  2020-01-18T12:00:00+00:00  2020-01-18T20:00:00+08:00
# 429                40  2020-01-18T13:00:00+00:00  2020-01-18T21:00:00+08:00
# 430                40  2020-01-18T14:00:00+00:00  2020-01-18T22:00:00+08:00
# 431                40  2020-01-18T15:00:00+00:00  2020-01-18T23:00:00+08:00
#
# [432 rows x 45 columns]

# %%
df.apply(lambda x: parse_datetime(x.UTCdate,x.UTCtime),axis=1)
# Out:
# 0      2019-12-31T16:00:00+00:00
# 1      2019-12-31T17:00:00+00:00
# 2      2019-12-31T18:00:00+00:00
# 3      2019-12-31T19:00:00+00:00
# 4      2019-12-31T20:00:00+00:00
#                  ...
# 427    2020-01-18T11:00:00+00:00
# 428    2020-01-18T12:00:00+00:00
# 429    2020-01-18T13:00:00+00:00
# 430    2020-01-18T14:00:00+00:00
# 431    2020-01-18T15:00:00+00:00
# Length: 432, dtype: object

# %%
def parse_datetime(date: str, hour: str) -> str:
    datetime = str(pendulum.from_format(f'{date} {int(int(hour) / 100)}', 'YYYY-MM-DD H'))
    return datetime

# %%
date,hour = df.UTCdate[17],df.UTCtime[17]
date,hour
# Out:
# ('2020-01-01', '900')

# %%
import pendulum

print(f'{date} {int(hour) / 100}')
str(pendulum.from_format(f'{date} {int(int(hour) / 100)}', 'YYYY-MM-DD H'))
# Out:
# 2020-01-01 9.0
# '2020-01-01T09:00:00+00:00'

# %%
df = pd.merge(hourly,daily,how='left',on='date')

# %%
import pendulum

start = pendulum.datetime(2016,1, 1)
end = pendulum.yesterday()
period = pendulum.period(start, end)

list(period.range("days",amount=35))
# Out:
# [DateTime(2016, 1, 1, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2016, 2, 5, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2016, 3, 11, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2016, 4, 15, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2016, 5, 20, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2016, 6, 24, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2016, 7, 29, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2016, 9, 2, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2016, 10, 7, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2016, 11, 11, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2016, 12, 16, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2017, 1, 20, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2017, 2, 24, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2017, 3, 31, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2017, 5, 5, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2017, 6, 9, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2017, 7, 14, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2017, 8, 18, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2017, 9, 22, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2017, 10, 27, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2017, 12, 1, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2018, 1, 5, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2018, 2, 9, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2018, 3, 16, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2018, 4, 20, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2018, 5, 25, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2018, 6, 29, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2018, 8, 3, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2018, 9, 7, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2018, 10, 12, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2018, 11, 16, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2018, 12, 21, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2019, 1, 25, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2019, 3, 1, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2019, 4, 5, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2019, 5, 10, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2019, 6, 14, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2019, 7, 19, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2019, 8, 23, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2019, 9, 27, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2019, 11, 1, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2019, 12, 6, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2020, 1, 10, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2020, 2, 14, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2020, 3, 20, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2020, 4, 24, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2020, 5, 29, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2020, 7, 3, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2020, 8, 7, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2020, 9, 11, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2020, 10, 16, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2020, 11, 20, 0, 0, 0, tzinfo=Timezone('UTC')),
#  DateTime(2020, 12, 25, 0, 0, 0, tzinfo=Timezone('UTC'))]

# %%
pendulum.Period??
# Out:
# Init signature: pendulum.Period(start, end, absolute=False)
# Source:
# class Period(Duration):
#     """
#     Duration class that is aware of the datetimes that generated the
#     time difference.
#     """
#
#     def __new__(cls, start, end, absolute=False):
#         if isinstance(start, datetime) and isinstance(end, datetime):
#             if (
#                 start.tzinfo is None
#                 and end.tzinfo is not None
#                 or start.tzinfo is not None
#                 and end.tzinfo is None
#             ):
#                 raise TypeError("can't compare offset-naive and offset-aware datetimes")
#
#         if absolute and start > end:
#             end, start = start, end
#
#         _start = start
#         _end = end
#         if isinstance(start, pendulum.DateTime):
#             if _HAS_FOLD:
#                 _start = datetime(
#                     start.year,
#                     start.month,
#                     start.day,
#                     start.hour,
#                     start.minute,
#                     start.second,
#                     start.microsecond,
#                     tzinfo=start.tzinfo,
#                     fold=start.fold,
#                 )
#             else:
#                 _start = datetime(
#                     start.year,
#                     start.month,
#                     start.day,
#                     start.hour,
#                     start.minute,
#                     start.second,
#                     start.microsecond,
#                     tzinfo=start.tzinfo,
#                 )
#         elif isinstance(start, pendulum.Date):
#             _start = date(start.year, start.month, start.day)
#
#         if isinstance(end, pendulum.DateTime):
#             if _HAS_FOLD:
#                 _end = datetime(
#                     end.year,
#                     end.month,
#                     end.day,
#                     end.hour,
#                     end.minute,
#                     end.second,
#                     end.microsecond,
#                     tzinfo=end.tzinfo,
#                     fold=end.fold,
#                 )
#             else:
#                 _end = datetime(
#                     end.year,
#                     end.month,
#                     end.day,
#                     end.hour,
#                     end.minute,
#                     end.second,
#                     end.microsecond,
#                     tzinfo=end.tzinfo,
#                 )
#         elif isinstance(end, pendulum.Date):
#             _end = date(end.year, end.month, end.day)
#
#         # Fixing issues with datetime.__sub__()
#         # not handling offsets if the tzinfo is the same
#         if (
#             isinstance(_start, datetime)
#             and isinstance(_end, datetime)
#             and _start.tzinfo is _end.tzinfo
#         ):
#             if _start.tzinfo is not None:
#                 _start = (_start - start.utcoffset()).replace(tzinfo=None)
#
#             if isinstance(end, datetime) and _end.tzinfo is not None:
#                 _end = (_end - end.utcoffset()).replace(tzinfo=None)
#
#         delta = _end - _start
#
#         return super(Period, cls).__new__(cls, seconds=delta.total_seconds())
#
#     def __init__(self, start, end, absolute=False):
#         super(Period, self).__init__()
#
#         if not isinstance(start, pendulum.Date):
#             if isinstance(start, datetime):
#                 start = pendulum.instance(start)
#             else:
#                 start = pendulum.date(start.year, start.month, start.day)
#
#             _start = start
#         else:
#             if isinstance(start, pendulum.DateTime):
#                 _start = datetime(
#                     start.year,
#                     start.month,
#                     start.day,
#                     start.hour,
#                     start.minute,
#                     start.second,
#                     start.microsecond,
#                     tzinfo=start.tzinfo,
#                 )
#             else:
#                 _start = date(start.year, start.month, start.day)
#
#         if not isinstance(end, pendulum.Date):
#             if isinstance(end, datetime):
#                 end = pendulum.instance(end)
#             else:
#                 end = pendulum.date(end.year, end.month, end.day)
#
#             _end = end
#         else:
#             if isinstance(end, pendulum.DateTime):
#                 _end = datetime(
#                     end.year,
#                     end.month,
#                     end.day,
#                     end.hour,
#                     end.minute,
#                     end.second,
#                     end.microsecond,
#                     tzinfo=end.tzinfo,
#                 )
#             else:
#                 _end = date(end.year, end.month, end.day)
#
#         self._invert = False
#         if start > end:
#             self._invert = True
#
#             if absolute:
#                 end, start = start, end
#                 _end, _start = _start, _end
#
#         self._absolute = absolute
#         self._start = start
#         self._end = end
#         self._delta = precise_diff(_start, _end)
#
#     @property
#     def years(self):
#         return self._delta.years
#
#     @property
#     def months(self):
#         return self._delta.months
#
#     @property
#     def weeks(self):
#         return abs(self._delta.days) // 7 * self._sign(self._delta.days)
#
#     @property
#     def days(self):
#         return self._days
#
#     @property
#     def remaining_days(self):
#         return abs(self._delta.days) % 7 * self._sign(self._days)
#
#     @property
#     def hours(self):
#         return self._delta.hours
#
#     @property
#     def minutes(self):
#         return self._delta.minutes
#
#     @property
#     def start(self):
#         return self._start
#
#     @property
#     def end(self):
#         return self._end
#
#     def in_years(self):
#         """
#         Gives the duration of the Period in full years.
#
#         :rtype: int
#         """
#         return self.years
#
#     def in_months(self):
#         """
#         Gives the duration of the Period in full months.
#
#         :rtype: int
#         """
#         return self.years * MONTHS_PER_YEAR + self.months
#
#     def in_weeks(self):
#         days = self.in_days()
#         sign = 1
#
#         if days < 0:
#             sign = -1
#
#         return sign * (abs(days) // 7)
#
#     def in_days(self):
#         return self._delta.total_days
#
#     def in_words(self, locale=None, separator=" "):
#         """
#         Get the current interval in words in the current locale.
#
#         Ex: 6 jours 23 heures 58 minutes
#
#         :param locale: The locale to use. Defaults to current locale.
#         :type locale: str
#
#         :param separator: The separator to use between each unit
#         :type separator: str
#
#         :rtype: str
#         """
#         periods = [
#             ("year", self.years),
#             ("month", self.months),
#             ("week", self.weeks),
#             ("day", self.remaining_days),
#             ("hour", self.hours),
#             ("minute", self.minutes),
#             ("second", self.remaining_seconds),
#         ]
#
#         if locale is None:
#             locale = pendulum.get_locale()
#
#         locale = pendulum.locale(locale)
#         parts = []
#         for period in periods:
#             unit, count = period
#             if abs(count) > 0:
#                 translation = locale.translation(
#                     "units.{}.{}".format(unit, locale.plural(abs(count)))
#                 )
#                 parts.append(translation.format(count))
#
#         if not parts:
#             if abs(self.microseconds) > 0:
#                 unit = "units.second.{}".format(locale.plural(1))
#                 count = "{:.2f}".format(abs(self.microseconds) / 1e6)
#             else:
#                 unit = "units.microsecond.{}".format(locale.plural(0))
#                 count = 0
#             translation = locale.translation(unit)
#             parts.append(translation.format(count))
#
#         return decode(separator.join(parts))
#
#     def range(self, unit, amount=1):
#         method = "add"
#         op = operator.le
#         if not self._absolute and self.invert:
#             method = "subtract"
#             op = operator.ge
#
#         start, end = self.start, self.end
#
#         i = amount
#         while op(start, end):
#             yield start
#
#             start = getattr(self.start, method)(**{unit: i})
#
#             i += amount
#
#     def as_interval(self):
#         """
#         Return the Period as an Duration.
#
#         :rtype: Duration
#         """
#         return Duration(seconds=self.total_seconds())
#
#     def __iter__(self):
#         return self.range("days")
#
#     def __contains__(self, item):
#         return self.start <= item <= self.end
#
#     def __add__(self, other):
#         return self.as_interval().__add__(other)
#
#     __radd__ = __add__
#
#     def __sub__(self, other):
#         return self.as_interval().__sub__(other)
#
#     def __neg__(self):
#         return self.__class__(self.end, self.start, self._absolute)
#
#     def __mul__(self, other):
#         return self.as_interval().__mul__(other)
#
#     __rmul__ = __mul__
#
#     def __floordiv__(self, other):
#         return self.as_interval().__floordiv__(other)
#
#     def __truediv__(self, other):
#         return self.as_interval().__truediv__(other)
#
#     __div__ = __floordiv__
#
#     def __mod__(self, other):
#         return self.as_interval().__mod__(other)
#
#     def __divmod__(self, other):
#         return self.as_interval().__divmod__(other)
#
#     def __abs__(self):
#         return self.__class__(self.start, self.end, True)
#
#     def __repr__(self):
#         return "<Period [{} -> {}]>".format(self._start, self._end)
#
#     def __str__(self):
#         return self.__repr__()
#
#     def _cmp(self, other):
#         # Only needed for PyPy
#         assert isinstance(other, timedelta)
#
#         if isinstance(other, Period):
#             other = other.as_timedelta()
#
#         td = self.as_timedelta()
#
#         return 0 if td == other else 1 if td > other else -1
#
#     def _getstate(self, protocol=3):
#         start, end = self.start, self.end
#
#         if self._invert and self._absolute:
#             end, start = start, end
#
#         return (start, end, self._absolute)
#
#     def __reduce__(self):
#         return self.__reduce_ex__(2)
#
#     def __reduce_ex__(self, protocol):
#         return self.__class__, self._getstate(protocol)
#
#     def __hash__(self):
#         return hash((self.start, self.end, self._absolute))
#
#     def __eq__(self, other):
#         if isinstance(other, Period):
#             return (self.start, self.end, self._absolute) == (
#                 other.start,
#                 other.end,
#                 other._absolute,
#             )
#         else:
#             return self.as_interval() == other
# File:           ~/Library/Caches/pypoetry/virtualenvs/airflow-pipelines-ELMc40Ku-py3.6/lib/python3.6/site-packages/pendulum/period.py
# Type:           type
# Subclasses:

# %%
raw_json['data']['weather'][2]['hourly']
# Out:
# [{'time': '0',
#   'UTCdate': '2021-01-02',
#   'UTCtime': '1600',
#   'isdaytime': 'no',
#   'tempC': '1',
#   'tempF': '34',
#   'windspeedMiles': '7',
#   'windspeedKmph': '12',
#   'winddirDegree': '70',
#   'winddir16Point': 'ENE',
#   'weatherCode': '113',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#   'weatherDesc': [{'value': 'Clear'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '76',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '3',
#   'HeatIndexC': '1',
#   'HeatIndexF': '34',
#   'DewPointC': '-3',
#   'DewPointF': '27',
#   'WindChillC': '-3',
#   'WindChillF': '28',
#   'WindGustMiles': '12',
#   'WindGustKmph': '19',
#   'FeelsLikeC': '-3',
#   'FeelsLikeF': '28',
#   'uvIndex': '1'},
#  {'time': '100',
#   'UTCdate': '2021-01-02',
#   'UTCtime': '1700',
#   'isdaytime': 'no',
#   'tempC': '1',
#   'tempF': '34',
#   'windspeedMiles': '8',
#   'windspeedKmph': '12',
#   'winddirDegree': '65',
#   'winddir16Point': 'ENE',
#   'weatherCode': '113',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#   'weatherDesc': [{'value': 'Clear'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '76',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '2',
#   'HeatIndexC': '1',
#   'HeatIndexF': '34',
#   'DewPointC': '-3',
#   'DewPointF': '27',
#   'WindChillC': '-3',
#   'WindChillF': '27',
#   'WindGustMiles': '12',
#   'WindGustKmph': '19',
#   'FeelsLikeC': '-3',
#   'FeelsLikeF': '27',
#   'uvIndex': '1'},
#  {'time': '200',
#   'UTCdate': '2021-01-02',
#   'UTCtime': '1800',
#   'isdaytime': 'no',
#   'tempC': '1',
#   'tempF': '34',
#   'windspeedMiles': '8',
#   'windspeedKmph': '12',
#   'winddirDegree': '60',
#   'winddir16Point': 'ENE',
#   'weatherCode': '113',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#   'weatherDesc': [{'value': 'Clear'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '75',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1030',
#   'pressureInches': '31',
#   'cloudcover': '1',
#   'HeatIndexC': '1',
#   'HeatIndexF': '34',
#   'DewPointC': '-3',
#   'DewPointF': '27',
#   'WindChillC': '-3',
#   'WindChillF': '27',
#   'WindGustMiles': '12',
#   'WindGustKmph': '19',
#   'FeelsLikeC': '-3',
#   'FeelsLikeF': '27',
#   'uvIndex': '1'},
#  {'time': '300',
#   'UTCdate': '2021-01-02',
#   'UTCtime': '1900',
#   'isdaytime': 'no',
#   'tempC': '1',
#   'tempF': '34',
#   'windspeedMiles': '8',
#   'windspeedKmph': '13',
#   'winddirDegree': '56',
#   'winddir16Point': 'NE',
#   'weatherCode': '113',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#   'weatherDesc': [{'value': 'Clear'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '74',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1030',
#   'pressureInches': '31',
#   'cloudcover': '0',
#   'HeatIndexC': '1',
#   'HeatIndexF': '34',
#   'DewPointC': '-3',
#   'DewPointF': '26',
#   'WindChillC': '-3',
#   'WindChillF': '27',
#   'WindGustMiles': '11',
#   'WindGustKmph': '18',
#   'FeelsLikeC': '-3',
#   'FeelsLikeF': '27',
#   'uvIndex': '1'},
#  {'time': '400',
#   'UTCdate': '2021-01-02',
#   'UTCtime': '2000',
#   'isdaytime': 'no',
#   'tempC': '1',
#   'tempF': '33',
#   'windspeedMiles': '8',
#   'windspeedKmph': '13',
#   'winddirDegree': '56',
#   'winddir16Point': 'ENE',
#   'weatherCode': '113',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#   'weatherDesc': [{'value': 'Clear'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '74',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '1',
#   'HeatIndexC': '1',
#   'HeatIndexF': '33',
#   'DewPointC': '-3',
#   'DewPointF': '26',
#   'WindChillC': '-3',
#   'WindChillF': '26',
#   'WindGustMiles': '12',
#   'WindGustKmph': '20',
#   'FeelsLikeC': '-3',
#   'FeelsLikeF': '26',
#   'uvIndex': '1'},
#  {'time': '500',
#   'UTCdate': '2021-01-02',
#   'UTCtime': '2100',
#   'isdaytime': 'no',
#   'tempC': '1',
#   'tempF': '33',
#   'windspeedMiles': '9',
#   'windspeedKmph': '14',
#   'winddirDegree': '57',
#   'winddir16Point': 'ENE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '74',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '1',
#   'HeatIndexC': '1',
#   'HeatIndexF': '33',
#   'DewPointC': '-3',
#   'DewPointF': '26',
#   'WindChillC': '-4',
#   'WindChillF': '26',
#   'WindGustMiles': '13',
#   'WindGustKmph': '21',
#   'FeelsLikeC': '-4',
#   'FeelsLikeF': '26',
#   'uvIndex': '1'},
#  {'time': '600',
#   'UTCdate': '2021-01-02',
#   'UTCtime': '2200',
#   'isdaytime': 'yes',
#   'tempC': '0',
#   'tempF': '33',
#   'windspeedMiles': '9',
#   'windspeedKmph': '14',
#   'winddirDegree': '57',
#   'winddir16Point': 'ENE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '75',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '2',
#   'HeatIndexC': '0',
#   'HeatIndexF': '33',
#   'DewPointC': '-4',
#   'DewPointF': '26',
#   'WindChillC': '-4',
#   'WindChillF': '25',
#   'WindGustMiles': '14',
#   'WindGustKmph': '22',
#   'FeelsLikeC': '-4',
#   'FeelsLikeF': '25',
#   'uvIndex': '2'},
#  {'time': '700',
#   'UTCdate': '2021-01-02',
#   'UTCtime': '2300',
#   'isdaytime': 'yes',
#   'tempC': '1',
#   'tempF': '33',
#   'windspeedMiles': '9',
#   'windspeedKmph': '15',
#   'winddirDegree': '62',
#   'winddir16Point': 'ENE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '75',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '4',
#   'HeatIndexC': '1',
#   'HeatIndexF': '33',
#   'DewPointC': '-3',
#   'DewPointF': '26',
#   'WindChillC': '-3',
#   'WindChillF': '26',
#   'WindGustMiles': '13',
#   'WindGustKmph': '22',
#   'FeelsLikeC': '-3',
#   'FeelsLikeF': '26',
#   'uvIndex': '2'},
#  {'time': '800',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '0',
#   'isdaytime': 'yes',
#   'tempC': '1',
#   'tempF': '34',
#   'windspeedMiles': '9',
#   'windspeedKmph': '15',
#   'winddirDegree': '66',
#   'winddir16Point': 'ENE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '75',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1032',
#   'pressureInches': '31',
#   'cloudcover': '7',
#   'HeatIndexC': '1',
#   'HeatIndexF': '34',
#   'DewPointC': '-3',
#   'DewPointF': '27',
#   'WindChillC': '-3',
#   'WindChillF': '27',
#   'WindGustMiles': '13',
#   'WindGustKmph': '21',
#   'FeelsLikeC': '-3',
#   'FeelsLikeF': '27',
#   'uvIndex': '2'},
#  {'time': '900',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '100',
#   'isdaytime': 'yes',
#   'tempC': '2',
#   'tempF': '35',
#   'windspeedMiles': '9',
#   'windspeedKmph': '15',
#   'winddirDegree': '71',
#   'winddir16Point': 'ENE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '75',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1032',
#   'pressureInches': '31',
#   'cloudcover': '9',
#   'HeatIndexC': '2',
#   'HeatIndexF': '35',
#   'DewPointC': '-2',
#   'DewPointF': '28',
#   'WindChillC': '-2',
#   'WindChillF': '28',
#   'WindGustMiles': '13',
#   'WindGustKmph': '21',
#   'FeelsLikeC': '-2',
#   'FeelsLikeF': '28',
#   'uvIndex': '2'},
#  {'time': '1000',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '200',
#   'isdaytime': 'yes',
#   'tempC': '3',
#   'tempF': '37',
#   'windspeedMiles': '9',
#   'windspeedKmph': '15',
#   'winddirDegree': '73',
#   'winddir16Point': 'ENE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '72',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1032',
#   'pressureInches': '31',
#   'cloudcover': '20',
#   'HeatIndexC': '3',
#   'HeatIndexF': '37',
#   'DewPointC': '-2',
#   'DewPointF': '29',
#   'WindChillC': '-1',
#   'WindChillF': '31',
#   'WindGustMiles': '12',
#   'WindGustKmph': '20',
#   'FeelsLikeC': '-1',
#   'FeelsLikeF': '31',
#   'uvIndex': '2'},
#  {'time': '1100',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '300',
#   'isdaytime': 'yes',
#   'tempC': '4',
#   'tempF': '39',
#   'windspeedMiles': '9',
#   'windspeedKmph': '14',
#   'winddirDegree': '75',
#   'winddir16Point': 'ENE',
#   'weatherCode': '122',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Overcast'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '69',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1032',
#   'pressureInches': '31',
#   'cloudcover': '31',
#   'HeatIndexC': '4',
#   'HeatIndexF': '39',
#   'DewPointC': '-1',
#   'DewPointF': '30',
#   'WindChillC': '1',
#   'WindChillF': '33',
#   'WindGustMiles': '12',
#   'WindGustKmph': '19',
#   'FeelsLikeC': '1',
#   'FeelsLikeF': '33',
#   'uvIndex': '1'},
#  {'time': '1200',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '400',
#   'isdaytime': 'yes',
#   'tempC': '5',
#   'tempF': '42',
#   'windspeedMiles': '9',
#   'windspeedKmph': '14',
#   'winddirDegree': '76',
#   'winddir16Point': 'ENE',
#   'weatherCode': '122',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Overcast'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '66',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '43',
#   'HeatIndexC': '5',
#   'HeatIndexF': '42',
#   'DewPointC': '-1',
#   'DewPointF': '31',
#   'WindChillC': '2',
#   'WindChillF': '36',
#   'WindGustMiles': '11',
#   'WindGustKmph': '17',
#   'FeelsLikeC': '2',
#   'FeelsLikeF': '36',
#   'uvIndex': '2'},
#  {'time': '1300',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '500',
#   'isdaytime': 'yes',
#   'tempC': '6',
#   'tempF': '42',
#   'windspeedMiles': '8',
#   'windspeedKmph': '13',
#   'winddirDegree': '70',
#   'winddir16Point': 'ENE',
#   'weatherCode': '122',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Overcast'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '66',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '61',
#   'HeatIndexC': '6',
#   'HeatIndexF': '42',
#   'DewPointC': '-0',
#   'DewPointF': '31',
#   'WindChillC': '3',
#   'WindChillF': '37',
#   'WindGustMiles': '10',
#   'WindGustKmph': '16',
#   'FeelsLikeC': '3',
#   'FeelsLikeF': '37',
#   'uvIndex': '2'},
#  {'time': '1400',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '600',
#   'isdaytime': 'yes',
#   'tempC': '6',
#   'tempF': '43',
#   'windspeedMiles': '8',
#   'windspeedKmph': '12',
#   'winddirDegree': '63',
#   'winddir16Point': 'ENE',
#   'weatherCode': '122',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Overcast'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '66',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1030',
#   'pressureInches': '31',
#   'cloudcover': '80',
#   'HeatIndexC': '6',
#   'HeatIndexF': '43',
#   'DewPointC': '0',
#   'DewPointF': '32',
#   'WindChillC': '3',
#   'WindChillF': '38',
#   'WindGustMiles': '10',
#   'WindGustKmph': '16',
#   'FeelsLikeC': '3',
#   'FeelsLikeF': '38',
#   'uvIndex': '2'},
#  {'time': '1500',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '700',
#   'isdaytime': 'yes',
#   'tempC': '6',
#   'tempF': '43',
#   'windspeedMiles': '7',
#   'windspeedKmph': '11',
#   'winddirDegree': '56',
#   'winddir16Point': 'ENE',
#   'weatherCode': '122',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Overcast'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '67',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1030',
#   'pressureInches': '31',
#   'cloudcover': '98',
#   'HeatIndexC': '6',
#   'HeatIndexF': '43',
#   'DewPointC': '0',
#   'DewPointF': '33',
#   'WindChillC': '4',
#   'WindChillF': '39',
#   'WindGustMiles': '9',
#   'WindGustKmph': '15',
#   'FeelsLikeC': '4',
#   'FeelsLikeF': '39',
#   'uvIndex': '2'},
#  {'time': '1600',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '800',
#   'isdaytime': 'yes',
#   'tempC': '6',
#   'tempF': '42',
#   'windspeedMiles': '7',
#   'windspeedKmph': '11',
#   'winddirDegree': '50',
#   'winddir16Point': 'NE',
#   'weatherCode': '122',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Overcast'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '69',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1030',
#   'pressureInches': '31',
#   'cloudcover': '91',
#   'HeatIndexC': '6',
#   'HeatIndexF': '42',
#   'DewPointC': '0',
#   'DewPointF': '33',
#   'WindChillC': '3',
#   'WindChillF': '38',
#   'WindGustMiles': '10',
#   'WindGustKmph': '15',
#   'FeelsLikeC': '3',
#   'FeelsLikeF': '38',
#   'uvIndex': '2'},
#  {'time': '1700',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '900',
#   'isdaytime': 'yes',
#   'tempC': '5',
#   'tempF': '41',
#   'windspeedMiles': '6',
#   'windspeedKmph': '10',
#   'winddirDegree': '44',
#   'winddir16Point': 'NE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '72',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1030',
#   'pressureInches': '31',
#   'cloudcover': '84',
#   'HeatIndexC': '5',
#   'HeatIndexF': '41',
#   'DewPointC': '1',
#   'DewPointF': '33',
#   'WindChillC': '3',
#   'WindChillF': '37',
#   'WindGustMiles': '10',
#   'WindGustKmph': '16',
#   'FeelsLikeC': '3',
#   'FeelsLikeF': '37',
#   'uvIndex': '3'},
#  {'time': '1800',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '1000',
#   'isdaytime': 'no',
#   'tempC': '5',
#   'tempF': '41',
#   'windspeedMiles': '6',
#   'windspeedKmph': '10',
#   'winddirDegree': '38',
#   'winddir16Point': 'NE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '75',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '76',
#   'HeatIndexC': '5',
#   'HeatIndexF': '41',
#   'DewPointC': '1',
#   'DewPointF': '33',
#   'WindChillC': '2',
#   'WindChillF': '36',
#   'WindGustMiles': '10',
#   'WindGustKmph': '17',
#   'FeelsLikeC': '2',
#   'FeelsLikeF': '36',
#   'uvIndex': '1'},
#  {'time': '1900',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '1100',
#   'isdaytime': 'no',
#   'tempC': '4',
#   'tempF': '40',
#   'windspeedMiles': '6',
#   'windspeedKmph': '10',
#   'winddirDegree': '42',
#   'winddir16Point': 'NE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '77',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '65',
#   'HeatIndexC': '4',
#   'HeatIndexF': '40',
#   'DewPointC': '1',
#   'DewPointF': '33',
#   'WindChillC': '2',
#   'WindChillF': '35',
#   'WindGustMiles': '10',
#   'WindGustKmph': '17',
#   'FeelsLikeC': '2',
#   'FeelsLikeF': '35',
#   'uvIndex': '1'},
#  {'time': '2000',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '1200',
#   'isdaytime': 'no',
#   'tempC': '4',
#   'tempF': '39',
#   'windspeedMiles': '6',
#   'windspeedKmph': '10',
#   'winddirDegree': '47',
#   'winddir16Point': 'NE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '79',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '53',
#   'HeatIndexC': '4',
#   'HeatIndexF': '39',
#   'DewPointC': '1',
#   'DewPointF': '33',
#   'WindChillC': '1',
#   'WindChillF': '34',
#   'WindGustMiles': '11',
#   'WindGustKmph': '17',
#   'FeelsLikeC': '1',
#   'FeelsLikeF': '34',
#   'uvIndex': '1'},
#  {'time': '2100',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '1300',
#   'isdaytime': 'no',
#   'tempC': '3',
#   'tempF': '38',
#   'windspeedMiles': '6',
#   'windspeedKmph': '10',
#   'winddirDegree': '52',
#   'winddir16Point': 'NE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '81',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '42',
#   'HeatIndexC': '3',
#   'HeatIndexF': '38',
#   'DewPointC': '0',
#   'DewPointF': '33',
#   'WindChillC': '1',
#   'WindChillF': '33',
#   'WindGustMiles': '11',
#   'WindGustKmph': '17',
#   'FeelsLikeC': '1',
#   'FeelsLikeF': '33',
#   'uvIndex': '1'},
#  {'time': '2200',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '1400',
#   'isdaytime': 'no',
#   'tempC': '3',
#   'tempF': '37',
#   'windspeedMiles': '6',
#   'windspeedKmph': '10',
#   'winddirDegree': '50',
#   'winddir16Point': 'NE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '85',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '40',
#   'HeatIndexC': '3',
#   'HeatIndexF': '37',
#   'DewPointC': '0',
#   'DewPointF': '33',
#   'WindChillC': '0',
#   'WindChillF': '32',
#   'WindGustMiles': '11',
#   'WindGustKmph': '18',
#   'FeelsLikeC': '0',
#   'FeelsLikeF': '32',
#   'uvIndex': '1'},
#  {'time': '2300',
#   'UTCdate': '2021-01-03',
#   'UTCtime': '1500',
#   'isdaytime': 'no',
#   'tempC': '2',
#   'tempF': '36',
#   'windspeedMiles': '7',
#   'windspeedKmph': '11',
#   'winddirDegree': '47',
#   'winddir16Point': 'NE',
#   'weatherCode': '116',
#   'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#   'weatherDesc': [{'value': 'Partly cloudy'}],
#   'precipMM': '0.0',
#   'precipInches': '0.0',
#   'humidity': '88',
#   'visibility': '10',
#   'visibilityMiles': '6',
#   'pressure': '1031',
#   'pressureInches': '31',
#   'cloudcover': '39',
#   'HeatIndexC': '2',
#   'HeatIndexF': '36',
#   'DewPointC': '1',
#   'DewPointF': '33',
#   'WindChillC': '-1',
#   'WindChillF': '31',
#   'WindGustMiles': '12',
#   'WindGustKmph': '19',
#   'FeelsLikeC': '-1',
#   'FeelsLikeF': '31',
#   'uvIndex': '1'}]

# %%
reduce(add,[[12,3],[2,3],[3,5,6]])
# Out:
# [12, 3, 2, 3, 3, 5, 6]

# %%
daily_data = []
for daily_json in process_raw_weather_json(raw_json=raw_json):
    daily_data.append(process_daily_data(raw_daily_json=daily_json))

# %%
import pandas as pd

pd.DataFrame.from_dict(daily_data)
# Out:
#           date maxtempC maxtempF mintempC mintempF avgtempC avgtempF  \
# 0   2021-01-01        6       42       -3       27        2       36
# 1   2021-01-02        7       44        1       34        4       39
# 2   2021-01-03        6       43        0       33        4       39
# 3   2021-01-04        6       43        1       34        4       39
# 4   2021-01-05        4       39        1       34        3       37
# 5   2021-01-06        4       39       -3       26        2       35
# 6   2021-01-07       -5       24      -10       15       -7       19
# 7   2021-01-08        2       35       -6       22       -1       30
# 8   2021-01-09        3       38       -4       25        0       32
# 9   2021-01-10        4       38       -2       29        1       34
# 10  2021-01-11        5       40       -1       30        2       36
# 11  2021-01-12       10       49        0       32        6       42
# 12  2021-01-13       15       58        5       40       10       50
# 13  2021-01-14       15       59        6       43       11       51
# 14  2021-01-15       11       52        5       42        8       47
# 15  2021-01-16        5       42        0       32        3       37
# 16  2021-01-17        7       44        1       33        4       39
# 17  2021-01-18       14       56        1       35        8       47
#
#    totalSnow_cm sunHour uvIndex   sunrise    sunset     moonrise   moonset  \
# 0           0.0     8.7       2  07:20 AM  05:21 PM     07:22 PM  09:02 AM
# 1           0.0     8.7       2  07:20 AM  05:22 PM     08:25 PM  09:46 AM
# 2           0.0     7.1       2  07:20 AM  05:23 PM     09:30 PM  10:25 AM
# 3           0.0     3.8       2  07:20 AM  05:23 PM     10:34 PM  11:00 AM
# 4           0.0     3.8       1  07:20 AM  05:24 PM     11:39 PM  11:34 AM
# 5           0.0     8.7       2  07:21 AM  05:25 PM  No moonrise  12:06 PM
# 6           0.0     3.8       2  07:21 AM  05:26 PM     12:43 AM  12:38 PM
# 7           0.0     8.7       2  07:21 AM  05:27 PM     01:50 AM  01:14 PM
# 8           0.0     8.7       2  07:21 AM  05:28 PM     02:58 AM  01:53 PM
# 9           0.1     7.1       2  07:21 AM  05:28 PM     04:08 AM  02:37 PM
# 10          0.0     8.7       2  07:21 AM  05:29 PM     05:17 AM  03:29 PM
# 11          0.0     8.7       3  07:20 AM  05:30 PM     06:23 AM  04:27 PM
# 12          0.0     8.7       4  07:20 AM  05:31 PM     07:24 AM  05:30 PM
# 13          0.0     5.4       4  07:20 AM  05:32 PM     08:16 AM  06:35 PM
# 14          0.0     8.7       3  07:20 AM  05:33 PM     09:01 AM  07:40 PM
# 15          0.0     8.7       1  07:20 AM  05:34 PM     09:39 AM  08:41 PM
# 16          0.0     8.7       1  07:19 AM  05:35 PM     10:11 AM  09:41 PM
# 17          0.0     8.7       3  07:19 AM  05:36 PM     10:41 AM  10:37 PM
#
#          moon_phase moon_illumination
# 0    Waning Gibbous                79
# 1    Waning Gibbous                71
# 2    Waning Gibbous                64
# 3    Waning Gibbous                57
# 4      Last Quarter                50
# 5      Last Quarter                42
# 6      Last Quarter                35
# 7      Last Quarter                28
# 8   Waning Crescent                20
# 9   Waning Crescent                13
# 10  Waning Crescent                 6
# 11         New Moon                 0
# 12         New Moon                 0
# 13  Waxing Crescent                 1
# 14  Waxing Crescent                 8
# 15  Waxing Crescent                16
# 16  Waxing Crescent                23
# 17  Waxing Crescent                30

# %%
from typing import List

# %%
df.dtypes
# Out:
# isdaytime            object
# tempC                object
# tempF                object
# windspeedMiles       object
# windspeedKmph        object
# winddirDegree        object
# winddir16Point       object
# weatherCode          object
# weatherDesc          object
# precipMM             object
# precipInches         object
# humidity             object
# visibility           object
# visibilityMiles      object
# pressure             object
# pressureInches       object
# cloudcover           object
# HeatIndexC           object
# HeatIndexF           object
# DewPointC            object
# DewPointF            object
# WindChillC           object
# WindChillF           object
# WindGustMiles        object
# WindGustKmph         object
# FeelsLikeC           object
# FeelsLikeF           object
# uvIndex_x            object
# maxtempC             object
# maxtempF             object
# mintempC             object
# mintempF             object
# avgtempC             object
# avgtempF             object
# totalSnow_cm         object
# sunHour              object
# uvIndex_y            object
# sunrise              object
# sunset               object
# moonrise             object
# moonset              object
# moon_phase           object
# moon_illumination    object
# utc_datetime         object
# local_datetime       object
# dtype: object
